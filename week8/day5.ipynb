# %% [markdown]
# # The Price is Right
#
# The final step is to build a User Interface
#
# We will use more advanced aspects of Gradio - building piece by piece.

# %%
import gradio as gr
from deal_agent_framework import DealAgentFramework
from agents.deals import Opportunity, Deal

# %%
with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">The Price is Right - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Autonomous agent framework that finds online deals, collaborating with a proprietary fine-tuned LLM deployed on Modal, and a RAG pipeline with a frontier model and Chroma.</div>')
        

ui.launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Updated to change from height to max_height due to change in Gradio v5
# With much thanks to student Ed B. for raising this

with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    initial_deal = Deal(product_description="Example description", price=100.0, url="https://cnn.com")
    initial_opportunity = Opportunity(deal=initial_deal, estimate=200.0, discount=100.0)
    opportunities = gr.State([initial_opportunity])

    def get_table(opps):
        return [[opp.deal.product_description, opp.deal.price, opp.estimate, opp.discount, opp.deal.url] for opp in opps]

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">"The Price is Right" - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Deals surfaced so far:</div>')
    with gr.Row():
        opportunities_dataframe = gr.Dataframe(
            headers=["Description", "Price", "Estimate", "Discount", "URL"],
            wrap=True,
            column_widths=[4, 1, 1, 1, 2],
            row_count=10,
            col_count=5,
            max_height=400,
        )

    ui.load(get_table, inputs=[opportunities], outputs=[opportunities_dataframe])

ui.launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7861/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
agent_framework = DealAgentFramework()
agent_framework.init_agents_as_needed()

with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    initial_deal = Deal(product_description="Example description", price=100.0, url="https://cnn.com")
    initial_opportunity = Opportunity(deal=initial_deal, estimate=200.0, discount=100.0)
    opportunities = gr.State([initial_opportunity])

    def get_table(opps):
        return [[opp.deal.product_description, opp.deal.price, opp.estimate, opp.discount, opp.deal.url] for opp in opps]

    def do_select(opportunities, selected_index: gr.SelectData):
        row = selected_index.index[0]
        opportunity = opportunities[row]
        agent_framework.planner.messenger.alert(opportunity)

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">"The Price is Right" - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Deals surfaced so far:</div>')
    with gr.Row():
        opportunities_dataframe = gr.Dataframe(
            headers=["Description", "Price", "Estimate", "Discount", "URL"],
            wrap=True,
            column_widths=[4, 1, 1, 1, 2],
            row_count=10,
            col_count=5,
            max_height=400,
        )

    ui.load(get_table, inputs=[opportunities], outputs=[opportunities_dataframe])
    opportunities_dataframe.select(do_select, inputs=[opportunities], outputs=[])

ui.launch(inbrowser=True)

# %% [markdown]
# # Time for the code
#
# And now we'll move to the price_is_right.py code

# %%
# Reset memory back to 2 deals discovered in the past

from deal_agent_framework import DealAgentFramework
DealAgentFramework.reset_memory()

# %%
import logging
root = logging.getLogger()
root.setLevel(logging.INFO)

# %% [markdown]
# # Running the final product
#
# ## Just hit shift + enter in the next cell, and let the deals flow in!!

# %%
# !uv run price_is_right.py
# Out:
# * Running on local URL:  http://127.0.0.1:7862
# * To create a public link, set `share=True` in `launch()`.
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] Use pytorch device_name: mps
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] Use pytorch device_name: mps
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-09-06 15:48:11 +0530] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2026-09-06 15:48:14 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2026-09-06 15:48:14 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2026-09-06 15:48:14 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is initializing
# [2026-09-06 15:48:14 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is initializing
# [2026-09-06 15:48:15 +0530] [Agents] [INFO] Neural Network is using mps
# [2026-09-06 15:48:15 +0530] [Agents] [INFO] Neural Network is using mps
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is ready and weights are loaded
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is ready and weights are loaded
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover and Claude
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover and Claude
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] Kicking off Planning Agent
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] Kicking off Planning Agent
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2026-09-06 15:48:16 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2026-09-06 15:48:29 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent received 27 deals not already scraped
# [2026-09-06 15:48:29 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent received 27 deals not already scraped
# [2026-09-06 15:48:29 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Outputs
# [2026-09-06 15:48:29 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Outputs
# [2026-09-06 15:48:49 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2026-09-06 15:48:49 +0530] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2026-09-06 15:48:49 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-06 15:48:49 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-06 15:48:49 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-06 15:48:49 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 15:48:49 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2:3b; provider = ollama
# [2026-09-06 15:48:49 +0530] [Agents] [INFO]
# LiteLLM completion() model= llama3.2:3b; provider = ollama
# [2026-09-06 15:48:49 +0530] [Agents] [INFO]
# LiteLLM completion() model= llama3.2:3b; provider = ollama
# 15:48:51 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-06 15:48:51 +0530] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-06 15:48:51 +0530] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-06 15:48:51 +0530] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2:3b
# [2026-09-06 15:48:51 +0530] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2:3b
# [2026-09-06 15:48:51 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-06 15:48:51 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-06 15:49:30 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $110.00
# [2026-09-06 15:49:30 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $110.00
# [2026-09-06 15:49:30 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-06 15:49:30 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  1.25it/s]
# [2026-09-06 15:49:31 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-06 15:49:31 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-06 15:49:31 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call llama3.2:3b with context including 5 similar products
# [2026-09-06 15:49:31 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call llama3.2:3b with context including 5 similar products
# [2026-09-06 15:49:32 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $250.00
# [2026-09-06 15:49:32 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $250.00
# [2026-09-06 15:49:32 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-06 15:49:32 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-06 15:49:32 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $109.28
# [2026-09-06 15:49:32 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $109.28
# [2026-09-06 15:49:32 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $123.93
# [2026-09-06 15:49:32 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $123.93
# [2026-09-06 15:49:32 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-56.07
# [2026-09-06 15:49:32 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-56.07
# [2026-09-06 15:49:32 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-06 15:49:32 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-06 15:49:32 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-06 15:49:32 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 15:49:32 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2:3b; provider = ollama
# [2026-09-06 15:49:32 +0530] [Agents] [INFO]
# LiteLLM completion() model= llama3.2:3b; provider = ollama
# [2026-09-06 15:49:32 +0530] [Agents] [INFO]
# LiteLLM completion() model= llama3.2:3b; provider = ollama
# 15:49:33 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-06 15:49:33 +0530] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-06 15:49:33 +0530] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-06 15:49:33 +0530] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2:3b
# [2026-09-06 15:49:33 +0530] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2:3b
# [2026-09-06 15:49:33 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-06 15:49:33 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-06 15:49:35 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $500.00
# [2026-09-06 15:49:35 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $500.00
# [2026-09-06 15:49:35 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-06 15:49:35 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  3.08it/s]
# [2026-09-06 15:49:35 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-06 15:49:35 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-06 15:49:35 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call llama3.2:3b with context including 5 similar products
# [2026-09-06 15:49:35 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call llama3.2:3b with context including 5 similar products
# [2026-09-06 15:49:36 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $499.99
# [2026-09-06 15:49:36 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $499.99
# [2026-09-06 15:49:36 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-06 15:49:36 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-06 15:49:36 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $502.74
# [2026-09-06 15:49:36 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $502.74
# [2026-09-06 15:49:36 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $500.27
# [2026-09-06 15:49:36 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $500.27
# [2026-09-06 15:49:36 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $360.27
# [2026-09-06 15:49:36 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $360.27
# [2026-09-06 15:49:36 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-06 15:49:36 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-06 15:49:36 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-06 15:49:36 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 15:49:36 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2:3b; provider = ollama
# [2026-09-06 15:49:36 +0530] [Agents] [INFO]
# LiteLLM completion() model= llama3.2:3b; provider = ollama
# [2026-09-06 15:49:36 +0530] [Agents] [INFO]
# LiteLLM completion() model= llama3.2:3b; provider = ollama
# 15:49:38 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-06 15:49:38 +0530] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-06 15:49:38 +0530] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-06 15:49:38 +0530] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2:3b
# [2026-09-06 15:49:38 +0530] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2:3b
# [2026-09-06 15:49:38 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-06 15:49:38 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-06 15:49:39 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $110.00
# [2026-09-06 15:49:39 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $110.00
# [2026-09-06 15:49:39 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-06 15:49:39 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  9.28it/s]
# [2026-09-06 15:49:39 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-06 15:49:39 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-06 15:49:39 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call llama3.2:3b with context including 5 similar products
# [2026-09-06 15:49:39 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call llama3.2:3b with context including 5 similar products
# [2026-09-06 15:49:40 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $149.99
# [2026-09-06 15:49:40 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $149.99
# [2026-09-06 15:49:40 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-06 15:49:40 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-06 15:49:40 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $106.62
# [2026-09-06 15:49:40 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $106.62
# [2026-09-06 15:49:40 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $113.66
# [2026-09-06 15:49:40 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $113.66
# [2026-09-06 15:49:40 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $53.66
# [2026-09-06 15:49:40 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $53.66
# [2026-09-06 15:49:40 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-06 15:49:40 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-06 15:49:40 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-06 15:49:40 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 15:49:40 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2:3b; provider = ollama
# [2026-09-06 15:49:40 +0530] [Agents] [INFO]
# LiteLLM completion() model= llama3.2:3b; provider = ollama
# [2026-09-06 15:49:40 +0530] [Agents] [INFO]
# LiteLLM completion() model= llama3.2:3b; provider = ollama
# 15:49:41 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-06 15:49:41 +0530] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-06 15:49:41 +0530] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-06 15:49:41 +0530] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2:3b
# [2026-09-06 15:49:41 +0530] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2:3b
# [2026-09-06 15:49:41 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-06 15:49:41 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-06 15:49:42 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $60.00
# [2026-09-06 15:49:42 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $60.00
# [2026-09-06 15:49:42 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-06 15:49:42 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00,  8.77it/s]
# [2026-09-06 15:49:42 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-06 15:49:42 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-06 15:49:42 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call llama3.2:3b with context including 5 similar products
# [2026-09-06 15:49:42 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call llama3.2:3b with context including 5 similar products
# [2026-09-06 15:49:44 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $149.95
# [2026-09-06 15:49:44 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $149.95
# [2026-09-06 15:49:44 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-06 15:49:44 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-06 15:49:44 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $91.50
# [2026-09-06 15:49:44 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $91.50
# [2026-09-06 15:49:44 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $72.15
# [2026-09-06 15:49:44 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $72.15
# [2026-09-06 15:49:44 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-57.85
# [2026-09-06 15:49:44 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-57.85
# [2026-09-06 15:49:44 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-06 15:49:44 +0530] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2026-09-06 15:49:44 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# [2026-09-06 15:49:44 +0530] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - preprocessing text
# 15:49:44 - LiteLLM:INFO: utils.py:3421 -
# LiteLLM completion() model= llama3.2:3b; provider = ollama
# [2026-09-06 15:49:44 +0530] [Agents] [INFO]
# LiteLLM completion() model= llama3.2:3b; provider = ollama
# [2026-09-06 15:49:44 +0530] [Agents] [INFO]
# LiteLLM completion() model= llama3.2:3b; provider = ollama
# 15:49:45 - LiteLLM:INFO: utils.py:1302 - Wrapper: Completed Call, calling success_handler
# [2026-09-06 15:49:45 +0530] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-06 15:49:45 +0530] [Agents] [INFO] Wrapper: Completed Call, calling success_handler
# [2026-09-06 15:49:45 +0530] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2:3b
# [2026-09-06 15:49:45 +0530] [Agents] [INFO] [Ensemble Agent] Pre-processed text using ollama/llama3.2:3b
# [2026-09-06 15:49:45 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-06 15:49:45 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2026-09-06 15:49:46 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $60.00
# [2026-09-06 15:49:46 +0530] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $60.00
# [2026-09-06 15:49:46 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2026-09-06 15:49:46 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 14.31it/s]
# [2026-09-06 15:49:46 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-06 15:49:46 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2026-09-06 15:49:46 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call llama3.2:3b with context including 5 similar products
# [2026-09-06 15:49:46 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call llama3.2:3b with context including 5 similar products
# [2026-09-06 15:49:47 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $129.99
# [2026-09-06 15:49:47 +0530] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $129.99
# [2026-09-06 15:49:47 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-06 15:49:47 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent is starting a prediction
# [2026-09-06 15:49:47 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $75.43
# [2026-09-06 15:49:47 +0530] [Agents] [INFO] [Neural Network Agent] Neural Network Agent completed - predicting $75.43
# [2026-09-06 15:49:47 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $68.54
# [2026-09-06 15:49:47 +0530] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $68.54
# [2026-09-06 15:49:47 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $48.54
# [2026-09-06 15:49:47 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $48.54
# [2026-09-06 15:49:47 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $360.27
# [2026-09-06 15:49:47 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $360.27
# [2026-09-06 15:49:47 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2026-09-06 15:49:47 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2026-09-06 15:49:48 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2026-09-06 15:49:48 +0530] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2026-09-06 15:49:48 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# [2026-09-06 15:49:48 +0530] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# [2026-09-06 15:49:48 +0530] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='The Insignia F50 Series 43', price=140.0, url='https://www.dealnews.com/products/Insignia/Insignia-F50-43-4-K-LED-UHD-Smart-Fire-TV/498711.html?iref=rss-c142') estimate=500.2731912841797 discount=360.2731912841797
# [2026-09-06 15:49:48 +0530] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='The Insignia F50 Series 43', price=140.0, url='https://www.dealnews.com/products/Insignia/Insignia-F50-43-4-K-LED-UHD-Smart-Fire-TV/498711.html?iref=rss-c142') estimate=500.2731912841797 discount=360.2731912841797
# ^C
# Traceback (most recent call last):
#   File "/Users/shubham/personal/ai-engineering/llm_engineering/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2958, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/shubham/personal/ai-engineering/llm_engineering/week8/price_is_right.py", line 196, in <module>
#     App().run()
#   File "/Users/shubham/personal/ai-engineering/llm_engineering/week8/price_is_right.py", line 192, in run
#     ui.launch(share=False, inbrowser=True)
#   File "/Users/shubham/personal/ai-engineering/llm_engineering/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2865, in launch
#     self.block_thread()
#   File "/Users/shubham/personal/ai-engineering/llm_engineering/.venv/lib/python3.12/site-packages/gradio/blocks.py", line 2962, in block_thread
#     self.server.close()
#   File "/Users/shubham/personal/ai-engineering/llm_engineering/.venv/lib/python3.12/site-packages/gradio/http_server.py", line 69, in close
#     self.thread.join(timeout=5)
#   File "/Users/shubham/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/threading.py", line 1153, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/Users/shubham/.local/share/uv/python/cpython-3.12.12-macos-aarch64-none/lib/python3.12/threading.py", line 1169, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#a22;">But wait!! There's more..</h2>
#             <span style="color:#a22;">If you're not fed up of product prices yet 😂 I've built this out some more!<br/>
#             If you look in my repo <a href="https://github.com/ed-donner/tech2ai">tech2ai</a>, in segment4 is a version that uses OpenAI Agents SDK for the AutonomousPlanningAgent, and makes use of MCP servers.  If you're intrigued by Agents and MCP, and would like to learn more, then I also have a companion course on this. This, along with my 2 other companion courses, are laid out in my <a href="https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/">complete AI curriculum</a>.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">CONGRATULATIONS AND THANK YOU!!!</h2>
#             <span style="color:#090;">
#                 It's so fabulous that you've made it to the very end! My heartiest congratulations. Please stay in touch! I'm <a href="https://www.linkedin.com/in/eddonner/">here on LinkedIn</a> if we're not already connected and I'm on X at <a href="https://x.com/edwarddonner">@edwarddonner</a>. And my editor would be cross with me if I didn't mention one more time: it makes a HUGE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. <br/><br/>Massive thanks again for putting up with me for 8 weeks and getting all the way to the final cell! I'm excited to hear all about your career as an LLM Engineer. If you post on LinkedIn about completing the course and tag me, then I'll weigh in to amplify your achievement. <br/><b>You could not have picked a better time to be in this field.</b>
#             </span>
#         </td>
#     </tr>
# </table>
